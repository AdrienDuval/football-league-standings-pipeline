# %% [markdown]
# # Ligue 1 STANDING (SINGLE SEASON)
#
# ## This is for testing purposes

# %%
import os
import json
import requests
import pandas as pd
from mysql import connector
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")
API_HOST = os.getenv("API_HOST")
API_SECRET = os.getenv("API_SECRET")
SEASON = 2025
LEAGUE_ID = 5
print(API_KEY)
# Out:
# jAgOFcvg5LCvM1zm

# %%
# url = f"https://livescore-api.com/api-client/leagues/table.json?competition_id={LEAGUE_ID}&key={API_KEY}&secret={API_SECRET}"
url = f"https://livescore-api.com/api-client/leagues/table.json?key={API_KEY}&secret={API_SECRET}&competition_id={LEAGUE_ID}&include_form=1"
headers = {"x-rapidapi-key": API_KEY, "x-rapidapi-host": API_HOST}

# https://livescore-api.com/api-client/leagues/table.json?competition_id=2&key=jAgOFcvg5LCvM1zm&secret=vTsEc5W4cHdOTPCdqS165wnaiZG41frw

querystring = {"league": LEAGUE_ID, "season": SEASON}
print(querystring)
# Out:
# {'league': 5, 'season': 2025}

# %% [markdown]
# # ----------------------EXTREACT----------------------

# %%
response = requests.get(url=url)

# %%
payload = response.json()
payload
# Out:
# {'success': True,
#  'data': {'table': [{'league_id': '0',
#     'season_id': '56',
#     'name': 'Marseille',
#     'rank': '1',
#     'points': '18',
#     'matches': '8',
#     'goal_diff': '14',
#     'goals_scored': '21',
#     'goals_conceded': '7',
#     'lost': '2',
#     'drawn': '0',
#     'won': '6',
#     'team_id': '68',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Paris Saint-Germain',
#     'rank': '2',
#     'points': '17',
#     'matches': '8',
#     'goal_diff': '8',
#     'goals_scored': '16',
#     'goals_conceded': '8',
#     'lost': '1',
#     'drawn': '2',
#     'won': '5',
#     'team_id': '59',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Strasbourg',
#     'rank': '3',
#     'points': '16',
#     'matches': '8',
#     'goal_diff': '7',
#     'goals_scored': '17',
#     'goals_conceded': '10',
#     'lost': '2',
#     'drawn': '1',
#     'won': '5',
#     'team_id': '76',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Lens',
#     'rank': '4',
#     'points': '16',
#     'matches': '8',
#     'goal_diff': '5',
#     'goals_scored': '12',
#     'goals_conceded': '7',
#     'lost': '2',
#     'drawn': '1',
#     'won': '5',
#     'team_id': '957',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Lyon',
#     'rank': '5',
#     'points': '15',
#     'matches': '8',
#     'goal_diff': '3',
#     'goals_scored': '11',
#     'goals_conceded': '8',
#     'lost': '3',
#     'drawn': '0',
#     'won': '5',
#     'team_id': '61',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Lille',
#     'rank': '6',
#     'points': '14',
#     'matches': '8',
#     'goal_diff': '6',
#     'goals_scored': '16',
#     'goals_conceded': '10',
#     'lost': '2',
#     'drawn': '2',
#     'won': '4',
#     'team_id': '74',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Monaco',
#     'rank': '7',
#     'points': '14',
#     'matches': '8',
#     'goal_diff': '4',
#     'goals_scored': '17',
#     'goals_conceded': '13',
#     'lost': '2',
#     'drawn': '2',
#     'won': '4',
#     'team_id': '60',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Toulouse',
#     'rank': '8',
#     'points': '13',
#     'matches': '8',
#     'goal_diff': '3',
#     'goals_scored': '15',
#     'goals_conceded': '12',
#     'lost': '3',
#     'drawn': '1',
#     'won': '4',
#     'team_id': '67',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Rennes',
#     'rank': '9',
#     'points': '11',
#     'matches': '8',
#     'goal_diff': '-1',
#     'goals_scored': '11',
#     'goals_conceded': '12',
#     'lost': '1',
#     'drawn': '5',
#     'won': '2',
#     'team_id': '72',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Nice',
#     'rank': '10',
#     'points': '11',
#     'matches': '8',
#     'goal_diff': '-2',
#     'goals_scored': '12',
#     'goals_conceded': '14',
#     'lost': '3',
#     'drawn': '2',
#     'won': '3',
#     'team_id': '69',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Paris FC',
#     'rank': '11',
#     'points': '10',
#     'matches': '8',
#     'goal_diff': '-2',
#     'goals_scored': '13',
#     'goals_conceded': '15',
#     'lost': '4',
#     'drawn': '1',
#     'won': '3',
#     'team_id': '322',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Brest',
#     'rank': '12',
#     'points': '9',
#     'matches': '8',
#     'goal_diff': '0',
#     'goals_scored': '14',
#     'goals_conceded': '14',
#     'lost': '3',
#     'drawn': '3',
#     'won': '2',
#     'team_id': '1090',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Lorient',
#     'rank': '13',
#     'points': '8',
#     'matches': '8',
#     'goal_diff': '-7',
#     'goals_scored': '12',
#     'goals_conceded': '19',
#     'lost': '4',
#     'drawn': '2',
#     'won': '2',
#     'team_id': '1092',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Auxerre',
#     'rank': '14',
#     'points': '7',
#     'matches': '8',
#     'goal_diff': '-5',
#     'goals_scored': '7',
#     'goals_conceded': '12',
#     'lost': '5',
#     'drawn': '1',
#     'won': '2',
#     'team_id': '314',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Nantes',
#     'rank': '15',
#     'points': '6',
#     'matches': '8',
#     'goal_diff': '-4',
#     'goals_scored': '5',
#     'goals_conceded': '9',
#     'lost': '4',
#     'drawn': '3',
#     'won': '1',
#     'team_id': '66',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Le Havre',
#     'rank': '16',
#     'points': '6',
#     'matches': '8',
#     'goal_diff': '-6',
#     'goals_scored': '10',
#     'goals_conceded': '16',
#     'lost': '4',
#     'drawn': '3',
#     'won': '1',
#     'team_id': '316',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Angers',
#     'rank': '17',
#     'points': '6',
#     'matches': '8',
#     'goal_diff': '-8',
#     'goals_scored': '4',
#     'goals_conceded': '12',
#     'lost': '4',
#     'drawn': '3',
#     'won': '1',
#     'team_id': '65',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Metz',
#     'rank': '18',
#     'points': '2',
#     'matches': '8',
#     'goal_diff': '-15',
#     'goals_scored': '5',
#     'goals_conceded': '20',
#     'lost': '6',
#     'drawn': '2',
#     'won': '0',
#     'team_id': '78',
#     'competition_id': '5',
#     'group_id': '4102',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3548'}]}}

# %%
formatted_response = json.dumps(payload, indent=4)

# %%
print(formatted_response)
# Out:
# {
#     "success": true,
#     "data": {
#         "table": [
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Marseille",
#                 "rank": "1",
#                 "points": "18",
#                 "matches": "8",
#                 "goal_diff": "14",
#                 "goals_scored": "21",
#                 "goals_conceded": "7",
#                 "lost": "2",
#                 "drawn": "0",
#                 "won": "6",
#                 "team_id": "68",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Paris Saint-Germain",
#                 "rank": "2",
#                 "points": "17",
#                 "matches": "8",
#                 "goal_diff": "8",
#                 "goals_scored": "16",
#                 "goals_conceded": "8",
#                 "lost": "1",
#                 "drawn": "2",
#                 "won": "5",
#                 "team_id": "59",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Strasbourg",
#                 "rank": "3",
#                 "points": "16",
#                 "matches": "8",
#                 "goal_diff": "7",
#                 "goals_scored": "17",
#                 "goals_conceded": "10",
#                 "lost": "2",
#                 "drawn": "1",
#                 "won": "5",
#                 "team_id": "76",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Lens",
#                 "rank": "4",
#                 "points": "16",
#                 "matches": "8",
#                 "goal_diff": "5",
#                 "goals_scored": "12",
#                 "goals_conceded": "7",
#                 "lost": "2",
#                 "drawn": "1",
#                 "won": "5",
#                 "team_id": "957",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Lyon",
#                 "rank": "5",
#                 "points": "15",
#                 "matches": "8",
#                 "goal_diff": "3",
#                 "goals_scored": "11",
#                 "goals_conceded": "8",
#                 "lost": "3",
#                 "drawn": "0",
#                 "won": "5",
#                 "team_id": "61",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Lille",
#                 "rank": "6",
#                 "points": "14",
#                 "matches": "8",
#                 "goal_diff": "6",
#                 "goals_scored": "16",
#                 "goals_conceded": "10",
#                 "lost": "2",
#                 "drawn": "2",
#                 "won": "4",
#                 "team_id": "74",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Monaco",
#                 "rank": "7",
#                 "points": "14",
#                 "matches": "8",
#                 "goal_diff": "4",
#                 "goals_scored": "17",
#                 "goals_conceded": "13",
#                 "lost": "2",
#                 "drawn": "2",
#                 "won": "4",
#                 "team_id": "60",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Toulouse",
#                 "rank": "8",
#                 "points": "13",
#                 "matches": "8",
#                 "goal_diff": "3",
#                 "goals_scored": "15",
#                 "goals_conceded": "12",
#                 "lost": "3",
#                 "drawn": "1",
#                 "won": "4",
#                 "team_id": "67",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Rennes",
#                 "rank": "9",
#                 "points": "11",
#                 "matches": "8",
#                 "goal_diff": "-1",
#                 "goals_scored": "11",
#                 "goals_conceded": "12",
#                 "lost": "1",
#                 "drawn": "5",
#                 "won": "2",
#                 "team_id": "72",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Nice",
#                 "rank": "10",
#                 "points": "11",
#                 "matches": "8",
#                 "goal_diff": "-2",
#                 "goals_scored": "12",
#                 "goals_conceded": "14",
#                 "lost": "3",
#                 "drawn": "2",
#                 "won": "3",
#                 "team_id": "69",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Paris FC",
#                 "rank": "11",
#                 "points": "10",
#                 "matches": "8",
#                 "goal_diff": "-2",
#                 "goals_scored": "13",
#                 "goals_conceded": "15",
#                 "lost": "4",
#                 "drawn": "1",
#                 "won": "3",
#                 "team_id": "322",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Brest",
#                 "rank": "12",
#                 "points": "9",
#                 "matches": "8",
#                 "goal_diff": "0",
#                 "goals_scored": "14",
#                 "goals_conceded": "14",
#                 "lost": "3",
#                 "drawn": "3",
#                 "won": "2",
#                 "team_id": "1090",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Lorient",
#                 "rank": "13",
#                 "points": "8",
#                 "matches": "8",
#                 "goal_diff": "-7",
#                 "goals_scored": "12",
#                 "goals_conceded": "19",
#                 "lost": "4",
#                 "drawn": "2",
#                 "won": "2",
#                 "team_id": "1092",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Auxerre",
#                 "rank": "14",
#                 "points": "7",
#                 "matches": "8",
#                 "goal_diff": "-5",
#                 "goals_scored": "7",
#                 "goals_conceded": "12",
#                 "lost": "5",
#                 "drawn": "1",
#                 "won": "2",
#                 "team_id": "314",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Nantes",
#                 "rank": "15",
#                 "points": "6",
#                 "matches": "8",
#                 "goal_diff": "-4",
#                 "goals_scored": "5",
#                 "goals_conceded": "9",
#                 "lost": "4",
#                 "drawn": "3",
#                 "won": "1",
#                 "team_id": "66",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Le Havre",
#                 "rank": "16",
#                 "points": "6",
#                 "matches": "8",
#                 "goal_diff": "-6",
#                 "goals_scored": "10",
#                 "goals_conceded": "16",
#                 "lost": "4",
#                 "drawn": "3",
#                 "won": "1",
#                 "team_id": "316",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Angers",
#                 "rank": "17",
#                 "points": "6",
#                 "matches": "8",
#                 "goal_diff": "-8",
#                 "goals_scored": "4",
#                 "goals_conceded": "12",
#                 "lost": "4",
#                 "drawn": "3",
#                 "won": "1",
#                 "team_id": "65",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Metz",
#                 "rank": "18",
#                 "points": "2",
#                 "matches": "8",
#                 "goal_diff": "-15",
#                 "goals_scored": "5",
#                 "goals_conceded": "20",
#                 "lost": "6",
#                 "drawn": "2",
#                 "won": "0",
#                 "team_id": "78",
#                 "competition_id": "5",
#                 "group_id": "4102",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3548"
#             }
#         ]
#     }
# }

# %%
standings_list = payload["data"]["table"]
formatted_standings = json.dumps(standings_list, indent=4)
print(formatted_standings)
# Out:
# [
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Marseille",
#         "rank": "1",
#         "points": "18",
#         "matches": "8",
#         "goal_diff": "14",
#         "goals_scored": "21",
#         "goals_conceded": "7",
#         "lost": "2",
#         "drawn": "0",
#         "won": "6",
#         "team_id": "68",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Paris Saint-Germain",
#         "rank": "2",
#         "points": "17",
#         "matches": "8",
#         "goal_diff": "8",
#         "goals_scored": "16",
#         "goals_conceded": "8",
#         "lost": "1",
#         "drawn": "2",
#         "won": "5",
#         "team_id": "59",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Strasbourg",
#         "rank": "3",
#         "points": "16",
#         "matches": "8",
#         "goal_diff": "7",
#         "goals_scored": "17",
#         "goals_conceded": "10",
#         "lost": "2",
#         "drawn": "1",
#         "won": "5",
#         "team_id": "76",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Lens",
#         "rank": "4",
#         "points": "16",
#         "matches": "8",
#         "goal_diff": "5",
#         "goals_scored": "12",
#         "goals_conceded": "7",
#         "lost": "2",
#         "drawn": "1",
#         "won": "5",
#         "team_id": "957",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Lyon",
#         "rank": "5",
#         "points": "15",
#         "matches": "8",
#         "goal_diff": "3",
#         "goals_scored": "11",
#         "goals_conceded": "8",
#         "lost": "3",
#         "drawn": "0",
#         "won": "5",
#         "team_id": "61",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Lille",
#         "rank": "6",
#         "points": "14",
#         "matches": "8",
#         "goal_diff": "6",
#         "goals_scored": "16",
#         "goals_conceded": "10",
#         "lost": "2",
#         "drawn": "2",
#         "won": "4",
#         "team_id": "74",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Monaco",
#         "rank": "7",
#         "points": "14",
#         "matches": "8",
#         "goal_diff": "4",
#         "goals_scored": "17",
#         "goals_conceded": "13",
#         "lost": "2",
#         "drawn": "2",
#         "won": "4",
#         "team_id": "60",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Toulouse",
#         "rank": "8",
#         "points": "13",
#         "matches": "8",
#         "goal_diff": "3",
#         "goals_scored": "15",
#         "goals_conceded": "12",
#         "lost": "3",
#         "drawn": "1",
#         "won": "4",
#         "team_id": "67",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Rennes",
#         "rank": "9",
#         "points": "11",
#         "matches": "8",
#         "goal_diff": "-1",
#         "goals_scored": "11",
#         "goals_conceded": "12",
#         "lost": "1",
#         "drawn": "5",
#         "won": "2",
#         "team_id": "72",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Nice",
#         "rank": "10",
#         "points": "11",
#         "matches": "8",
#         "goal_diff": "-2",
#         "goals_scored": "12",
#         "goals_conceded": "14",
#         "lost": "3",
#         "drawn": "2",
#         "won": "3",
#         "team_id": "69",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Paris FC",
#         "rank": "11",
#         "points": "10",
#         "matches": "8",
#         "goal_diff": "-2",
#         "goals_scored": "13",
#         "goals_conceded": "15",
#         "lost": "4",
#         "drawn": "1",
#         "won": "3",
#         "team_id": "322",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Brest",
#         "rank": "12",
#         "points": "9",
#         "matches": "8",
#         "goal_diff": "0",
#         "goals_scored": "14",
#         "goals_conceded": "14",
#         "lost": "3",
#         "drawn": "3",
#         "won": "2",
#         "team_id": "1090",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Lorient",
#         "rank": "13",
#         "points": "8",
#         "matches": "8",
#         "goal_diff": "-7",
#         "goals_scored": "12",
#         "goals_conceded": "19",
#         "lost": "4",
#         "drawn": "2",
#         "won": "2",
#         "team_id": "1092",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Auxerre",
#         "rank": "14",
#         "points": "7",
#         "matches": "8",
#         "goal_diff": "-5",
#         "goals_scored": "7",
#         "goals_conceded": "12",
#         "lost": "5",
#         "drawn": "1",
#         "won": "2",
#         "team_id": "314",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Nantes",
#         "rank": "15",
#         "points": "6",
#         "matches": "8",
#         "goal_diff": "-4",
#         "goals_scored": "5",
#         "goals_conceded": "9",
#         "lost": "4",
#         "drawn": "3",
#         "won": "1",
#         "team_id": "66",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Le Havre",
#         "rank": "16",
#         "points": "6",
#         "matches": "8",
#         "goal_diff": "-6",
#         "goals_scored": "10",
#         "goals_conceded": "16",
#         "lost": "4",
#         "drawn": "3",
#         "won": "1",
#         "team_id": "316",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Angers",
#         "rank": "17",
#         "points": "6",
#         "matches": "8",
#         "goal_diff": "-8",
#         "goals_scored": "4",
#         "goals_conceded": "12",
#         "lost": "4",
#         "drawn": "3",
#         "won": "1",
#         "team_id": "65",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Metz",
#         "rank": "18",
#         "points": "2",
#         "matches": "8",
#         "goal_diff": "-15",
#         "goals_scored": "5",
#         "goals_conceded": "20",
#         "lost": "6",
#         "drawn": "2",
#         "won": "0",
#         "team_id": "78",
#         "competition_id": "5",
#         "group_id": "4102",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3548"
#     }
# ]

# %% [markdown]
# # -------------------------TRNAANSFORM-------------------------

# %%
arseille_points = standings_list[0]['points']
print(arseille_points)
# Out:
# 18

# %%
rows = []
column_names = [
    "season",
    "position",
    "team__id",
    "team",
    "played",
    "won",
    "draw",
    "lost",
    "goals_for",
    "goals_against",
    "goal_diff",
    "points",
    "form",
]
for club in standings_list:
    season = 2025
    position = club["rank"]
    team_id = club["team_id"]
    team = club["name"]
    played = club["matches"]
    won = club["won"]
    draw = club["drawn"]
    lost = club["lost"]
    goals_for = club["goals_scored"]
    goals_against = club["goals_conceded"]
    goal_diff = club["goal_diff"]
    points = club["points"]
    form = "LLDDWW"

    tuple_of_club_records = (
        season,
        position,
        team_id,
        team,
        played,
        won,
        draw,
        lost,
        goals_for,
        goals_against,
        goal_diff,
        points,
        form,
    )
    rows.append(tuple_of_club_records)

# %%
print(rows)
# Out:
# [(2025, '1', '68', 'Marseille', '8', '6', '0', '2', '21', '7', '14', '18', 'LLDDWW'), (2025, '2', '59', 'Paris Saint-Germain', '8', '5', '2', '1', '16', '8', '8', '17', 'LLDDWW'), (2025, '3', '76', 'Strasbourg', '8', '5', '1', '2', '17', '10', '7', '16', 'LLDDWW'), (2025, '4', '957', 'Lens', '8', '5', '1', '2', '12', '7', '5', '16', 'LLDDWW'), (2025, '5', '61', 'Lyon', '8', '5', '0', '3', '11', '8', '3', '15', 'LLDDWW'), (2025, '6', '74', 'Lille', '8', '4', '2', '2', '16', '10', '6', '14', 'LLDDWW'), (2025, '7', '60', 'Monaco', '8', '4', '2', '2', '17', '13', '4', '14', 'LLDDWW'), (2025, '8', '67', 'Toulouse', '8', '4', '1', '3', '15', '12', '3', '13', 'LLDDWW'), (2025, '9', '72', 'Rennes', '8', '2', '5', '1', '11', '12', '-1', '11', 'LLDDWW'), (2025, '10', '69', 'Nice', '8', '3', '2', '3', '12', '14', '-2', '11', 'LLDDWW'), (2025, '11', '322', 'Paris FC', '8', '3', '1', '4', '13', '15', '-2', '10', 'LLDDWW'), (2025, '12', '1090', 'Brest', '8', '2', '3', '3', '14', '14', '0', '9', 'LLDDWW'), (2025, '13', '1092', 'Lorient', '8', '2', '2', '4', '12', '19', '-7', '8', 'LLDDWW'), (2025, '14', '314', 'Auxerre', '8', '2', '1', '5', '7', '12', '-5', '7', 'LLDDWW'), (2025, '15', '66', 'Nantes', '8', '1', '3', '4', '5', '9', '-4', '6', 'LLDDWW'), (2025, '16', '316', 'Le Havre', '8', '1', '3', '4', '10', '16', '-6', '6', 'LLDDWW'), (2025, '17', '65', 'Angers', '8', '1', '3', '4', '4', '12', '-8', '6', 'LLDDWW'), (2025, '18', '78', 'Metz', '8', '0', '2', '6', '5', '20', '-15', '2', 'LLDDWW')]

# %%
df = pd.DataFrame(rows, columns=column_names)
df.head(18)
# Out:
#     season position team__id                 team played won draw lost  \
# 0     2025        1       68            Marseille      8   6    0    2
# 1     2025        2       59  Paris Saint-Germain      8   5    2    1
# 2     2025        3       76           Strasbourg      8   5    1    2
# 3     2025        4      957                 Lens      8   5    1    2
# 4     2025        5       61                 Lyon      8   5    0    3
# 5     2025        6       74                Lille      8   4    2    2
# 6     2025        7       60               Monaco      8   4    2    2
# 7     2025        8       67             Toulouse      8   4    1    3
# 8     2025        9       72               Rennes      8   2    5    1
# 9     2025       10       69                 Nice      8   3    2    3
# 10    2025       11      322             Paris FC      8   3    1    4
# 11    2025       12     1090                Brest      8   2    3    3
# 12    2025       13     1092              Lorient      8   2    2    4
# 13    2025       14      314              Auxerre      8   2    1    5
# 14    2025       15       66               Nantes      8   1    3    4
# 15    2025       16      316             Le Havre      8   1    3    4
# 16    2025       17       65               Angers      8   1    3    4
# 17    2025       18       78                 Metz      8   0    2    6
#
#    goals_for goals_against goal_diff points    form
# 0         21             7        14     18  LLDDWW
# 1         16             8         8     17  LLDDWW
# 2         17            10         7     16  LLDDWW
# 3         12             7         5     16  LLDDWW
# 4         11             8         3     15  LLDDWW
# 5         16            10         6     14  LLDDWW
# 6         17            13         4     14  LLDDWW
# 7         15            12         3     13  LLDDWW
# 8         11            12        -1     11  LLDDWW
# 9         12            14        -2     11  LLDDWW
# 10        13            15        -2     10  LLDDWW
# 11        14            14         0      9  LLDDWW
# 12        12            19        -7      8  LLDDWW
# 13         7            12        -5      7  LLDDWW
# 14         5             9        -4      6  LLDDWW
# 15        10            16        -6      6  LLDDWW
# 16         4            12        -8      6  LLDDWW
# 17         5            20       -15      2  LLDDWW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         18 non-null     int64
#  1   position       18 non-null     object
#  2   team__id       18 non-null     object
#  3   team           18 non-null     object
#  4   played         18 non-null     object
#  5   won            18 non-null     object
#  6   draw           18 non-null     object
#  7   lost           18 non-null     object
#  8   goals_for      18 non-null     object
#  9   goals_against  18 non-null     object
#  10  goal_diff      18 non-null     object
#  11  points         18 non-null     object
#  12  form           18 non-null     object
# dtypes: int64(1), object(12)
# memory usage: 2.0+ KB

# %% [markdown]
# # ----------------------------------- LOAD -----------------------------------

# %%
MYSQL_HOST = os.getenv("MYSQL_HOST")
MYSQL_PORT = os.getenv("MYSQL_PORT")
MYSQL_USER = os.getenv("MYSQL_USER")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_DATABASE = os.getenv("MYSQL_DATABASE")
print(MYSQL_USER)
# Out:
# postgres

# %%
import psycopg2

# server_conn = connector.connect(
#     host = MYSQL_HOST,
#     port = MYSQL_PORT,
#     user = MYSQL_USER,
#     password = MYSQL_PASSWORD,
#     # connection_timeout = 10,
#     autocommit = False,
#     raise_on_warning=True
# )

try:
    server_conn = psycopg2.connect(
        database=MYSQL_DATABASE,
        host=MYSQL_HOST,
        port=MYSQL_PORT,
        user=MYSQL_USER,
        password=MYSQL_PASSWORD,
    )
    server_conn
    # Open a cursor to perform database operations
    cur = server_conn.cursor()



    cur.execute(
        """
        CREATE TABLE IF NOT EXISTS standings_ligue_1(
        id SERIAL,
        season INT NOT NULL,
        position INT NOT NULL,
        team_id INT NOT NULL,
        team VARCHAR(100) NOT NULL,
        played INT NOT NULL,
        won INT NOT NULL,
        draw INT NOT NULL,
        lost INT NOT NULL,
        goals_for INT NOT NULL,
        goals_against INT NOT NULL,
        goal_diff INT NOT NULL,
        points INT NOT NULL,
        form VARCHAR(6) NOT NULL,
        PRIMARY KEY (season,team_id),
        UNIQUE(season, position)
        );

        """
    )
    print("Connection to PostgresSQL succesfull!")

    sql_table = "standings_ligue_1"
    cur.execute("""
    SELECT EXISTS (
        SELECT FROM information_schema.tables 
        WHERE table_schema = 'public' 
        AND table_name = %s
    )
    """,(sql_table,))

    exists = cur.fetchone()[0]

    if not exists:
        raise SystemExit(f"❌ This table '{sql_table}' is NOT found... please create it.")
    else:
        print(f"✅ This table '{sql_table}' exists!")

except Exception as e:
    print("connection failed!", e)


# finally:
#     if server_conn:
#         # make the changes to the database persistent
#         server_conn.commit()
#         # close cursor and communication with the database
#         cur.close()
#         server_conn.close()
# Out:
# Connection to PostgresSQL succesfull!
# ✅ This table 'standings_ligue_1' exists!

# %%
table_cols = [
    "season",
    "position",
    "team__id",
    "team",
    "played",
    "won",
    "draw",
    "lost",
    "goals_for",
    "goals_against",
    "goal_diff",
    "points",
    "form",
]

standing_df = df[table_cols]

# %%
standings_records_tuples = standing_df.itertuples(index=False, name=None)

list_of_standings_records_tuples = list(standings_records_tuples)

# %%
UPSERT_SQL = f"""
INSERT INTO {sql_table}
(season, position, team_id, team, played, won, draw, lost, goals_for, goals_against, goal_diff, points, form)
VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
ON CONFLICT (season, team_id) DO UPDATE SET
position = EXCLUDED.position,
team = EXCLUDED.team,
played = EXCLUDED.played,
won = EXCLUDED.won,
draw = EXCLUDED.draw,
lost = EXCLUDED.lost,
goals_for = EXCLUDED.goals_for,
goals_against = EXCLUDED.goals_against,
goal_diff = EXCLUDED.goal_diff,
points = EXCLUDED.points,
form = EXCLUDED.form;
"""

# %%
no_of_rows_uploaded_to_mysql = len(list_of_standings_records_tuples)

# %%
try:
    cur.executemany(UPSERT_SQL, list_of_standings_records_tuples)
    server_conn.commit()
    print(f"[SUCCESS] - Upsert attempted for {no_of_rows_uploaded_to_mysql} rows!")

except Exception as e:
    server_conn.rollback()
    print(f"[ERROR] - ROlled back due to this...: {e}")
finally:
    cur.close()
    server_conn.close()
    print("All database connection was closed. \n\nClean up completed.")
# Out:
# [SUCCESS] - Upsert attempted for 18 rows!
# All database connection was closed.
#
# Clean up completed.
