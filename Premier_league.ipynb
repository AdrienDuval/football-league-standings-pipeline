# %% [markdown]
# # PREMIERE LEAGUE STANDING (SINGLE SEASON)
#
# ## This is for testing purposes

# %%
import os
import json
import requests
import pandas as pd
from mysql import connector
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")
API_HOST = os.getenv("API_HOST")
API_SECRET = os.getenv("API_SECRET")
SEASON = 2025
LEAGUE_ID = 2
print(API_KEY)
# Out:
# jAgOFcvg5LCvM1zm

# %%
# url = f"https://livescore-api.com/api-client/leagues/table.json?competition_id={LEAGUE_ID}&key={API_KEY}&secret={API_SECRET}"
url = f"https://livescore-api.com/api-client/leagues/table.json?key={API_KEY}&secret={API_SECRET}&competition_id={LEAGUE_ID}&include_form=1"
headers = {"x-rapidapi-key": API_KEY, "x-rapidapi-host": API_HOST}

# https://livescore-api.com/api-client/leagues/table.json?competition_id=2&key=jAgOFcvg5LCvM1zm&secret=vTsEc5W4cHdOTPCdqS165wnaiZG41frw

querystring = {"league": LEAGUE_ID, "season": SEASON}
print(querystring)
# Out:
# {'league': 2, 'season': 2025}

# %% [markdown]
# # ----------------------EXTREACT----------------------

# %%
response = requests.get(url=url)

# %%
payload = response.json()
payload
# Out:
# {'success': True,
#  'data': {'table': [{'league_id': '0',
#     'season_id': '56',
#     'name': 'Arsenal',
#     'rank': '1',
#     'points': '19',
#     'matches': '8',
#     'goal_diff': '12',
#     'goals_scored': '15',
#     'goals_conceded': '3',
#     'lost': '1',
#     'drawn': '1',
#     'won': '6',
#     'team_id': '18',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Manchester City',
#     'rank': '2',
#     'points': '16',
#     'matches': '8',
#     'goal_diff': '11',
#     'goals_scored': '17',
#     'goals_conceded': '6',
#     'lost': '2',
#     'drawn': '1',
#     'won': '5',
#     'team_id': '12',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'AFC Bournemouth',
#     'rank': '3',
#     'points': '15',
#     'matches': '8',
#     'goal_diff': '3',
#     'goals_scored': '14',
#     'goals_conceded': '11',
#     'lost': '1',
#     'drawn': '3',
#     'won': '4',
#     'team_id': '1',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Liverpool',
#     'rank': '4',
#     'points': '15',
#     'matches': '8',
#     'goal_diff': '3',
#     'goals_scored': '14',
#     'goals_conceded': '11',
#     'lost': '3',
#     'drawn': '0',
#     'won': '5',
#     'team_id': '7',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Chelsea',
#     'rank': '5',
#     'points': '14',
#     'matches': '8',
#     'goal_diff': '7',
#     'goals_scored': '16',
#     'goals_conceded': '9',
#     'lost': '2',
#     'drawn': '2',
#     'won': '4',
#     'team_id': '17',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Tottenham Hotspur',
#     'rank': '6',
#     'points': '14',
#     'matches': '8',
#     'goal_diff': '7',
#     'goals_scored': '14',
#     'goals_conceded': '7',
#     'lost': '2',
#     'drawn': '2',
#     'won': '4',
#     'team_id': '15',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Sunderland',
#     'rank': '7',
#     'points': '14',
#     'matches': '8',
#     'goal_diff': '3',
#     'goals_scored': '9',
#     'goals_conceded': '6',
#     'lost': '2',
#     'drawn': '2',
#     'won': '4',
#     'team_id': '500',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Crystal Palace',
#     'rank': '8',
#     'points': '13',
#     'matches': '8',
#     'goal_diff': '4',
#     'goals_scored': '12',
#     'goals_conceded': '8',
#     'lost': '1',
#     'drawn': '4',
#     'won': '3',
#     'team_id': '3',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Manchester United',
#     'rank': '9',
#     'points': '13',
#     'matches': '8',
#     'goal_diff': '-1',
#     'goals_scored': '11',
#     'goals_conceded': '12',
#     'lost': '3',
#     'drawn': '1',
#     'won': '4',
#     'team_id': '19',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Brighton & Hove Albion',
#     'rank': '10',
#     'points': '12',
#     'matches': '8',
#     'goal_diff': '1',
#     'goals_scored': '12',
#     'goals_conceded': '11',
#     'lost': '2',
#     'drawn': '3',
#     'won': '3',
#     'team_id': '2',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Aston Villa',
#     'rank': '11',
#     'points': '12',
#     'matches': '8',
#     'goal_diff': '0',
#     'goals_scored': '8',
#     'goals_conceded': '8',
#     'lost': '2',
#     'drawn': '3',
#     'won': '3',
#     'team_id': '495',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Everton',
#     'rank': '12',
#     'points': '11',
#     'matches': '8',
#     'goal_diff': '0',
#     'goals_scored': '9',
#     'goals_conceded': '9',
#     'lost': '3',
#     'drawn': '2',
#     'won': '3',
#     'team_id': '20',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Brentford',
#     'rank': '13',
#     'points': '10',
#     'matches': '8',
#     'goal_diff': '-1',
#     'goals_scored': '11',
#     'goals_conceded': '12',
#     'lost': '4',
#     'drawn': '1',
#     'won': '3',
#     'team_id': '489',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Newcastle United',
#     'rank': '14',
#     'points': '9',
#     'matches': '8',
#     'goal_diff': '0',
#     'goals_scored': '7',
#     'goals_conceded': '7',
#     'lost': '3',
#     'drawn': '3',
#     'won': '2',
#     'team_id': '9',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Fulham',
#     'rank': '15',
#     'points': '8',
#     'matches': '8',
#     'goal_diff': '-4',
#     'goals_scored': '8',
#     'goals_conceded': '12',
#     'lost': '4',
#     'drawn': '2',
#     'won': '2',
#     'team_id': '502',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Leeds United',
#     'rank': '16',
#     'points': '8',
#     'matches': '8',
#     'goal_diff': '-6',
#     'goals_scored': '7',
#     'goals_conceded': '13',
#     'lost': '4',
#     'drawn': '2',
#     'won': '2',
#     'team_id': '1131',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Burnley',
#     'rank': '17',
#     'points': '7',
#     'matches': '8',
#     'goal_diff': '-6',
#     'goals_scored': '9',
#     'goals_conceded': '15',
#     'lost': '5',
#     'drawn': '1',
#     'won': '2',
#     'team_id': '8',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Nottingham Forest',
#     'rank': '18',
#     'points': '5',
#     'matches': '8',
#     'goal_diff': '-10',
#     'goals_scored': '5',
#     'goals_conceded': '15',
#     'lost': '5',
#     'drawn': '2',
#     'won': '1',
#     'team_id': '487',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'West Ham United',
#     'rank': '19',
#     'points': '4',
#     'matches': '8',
#     'goal_diff': '-12',
#     'goals_scored': '6',
#     'goals_conceded': '18',
#     'lost': '6',
#     'drawn': '1',
#     'won': '1',
#     'team_id': '14',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'},
#    {'league_id': '0',
#     'season_id': '56',
#     'name': 'Wolverhampton Wanderers',
#     'rank': '20',
#     'points': '2',
#     'matches': '8',
#     'goal_diff': '-11',
#     'goals_scored': '5',
#     'goals_conceded': '16',
#     'lost': '6',
#     'drawn': '2',
#     'won': '0',
#     'team_id': '497',
#     'competition_id': '2',
#     'group_id': '4042',
#     'group_name': 'A',
#     'stage_name': 'Regular Season',
#     'stage_id': '3498'}]}}

# %%
formatted_response = json.dumps(payload, indent=4)

# %%
print(formatted_response)
# Out:
# {
#     "success": true,
#     "data": {
#         "table": [
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Arsenal",
#                 "rank": "1",
#                 "points": "19",
#                 "matches": "8",
#                 "goal_diff": "12",
#                 "goals_scored": "15",
#                 "goals_conceded": "3",
#                 "lost": "1",
#                 "drawn": "1",
#                 "won": "6",
#                 "team_id": "18",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Manchester City",
#                 "rank": "2",
#                 "points": "16",
#                 "matches": "8",
#                 "goal_diff": "11",
#                 "goals_scored": "17",
#                 "goals_conceded": "6",
#                 "lost": "2",
#                 "drawn": "1",
#                 "won": "5",
#                 "team_id": "12",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "AFC Bournemouth",
#                 "rank": "3",
#                 "points": "15",
#                 "matches": "8",
#                 "goal_diff": "3",
#                 "goals_scored": "14",
#                 "goals_conceded": "11",
#                 "lost": "1",
#                 "drawn": "3",
#                 "won": "4",
#                 "team_id": "1",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Liverpool",
#                 "rank": "4",
#                 "points": "15",
#                 "matches": "8",
#                 "goal_diff": "3",
#                 "goals_scored": "14",
#                 "goals_conceded": "11",
#                 "lost": "3",
#                 "drawn": "0",
#                 "won": "5",
#                 "team_id": "7",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Chelsea",
#                 "rank": "5",
#                 "points": "14",
#                 "matches": "8",
#                 "goal_diff": "7",
#                 "goals_scored": "16",
#                 "goals_conceded": "9",
#                 "lost": "2",
#                 "drawn": "2",
#                 "won": "4",
#                 "team_id": "17",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Tottenham Hotspur",
#                 "rank": "6",
#                 "points": "14",
#                 "matches": "8",
#                 "goal_diff": "7",
#                 "goals_scored": "14",
#                 "goals_conceded": "7",
#                 "lost": "2",
#                 "drawn": "2",
#                 "won": "4",
#                 "team_id": "15",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Sunderland",
#                 "rank": "7",
#                 "points": "14",
#                 "matches": "8",
#                 "goal_diff": "3",
#                 "goals_scored": "9",
#                 "goals_conceded": "6",
#                 "lost": "2",
#                 "drawn": "2",
#                 "won": "4",
#                 "team_id": "500",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Crystal Palace",
#                 "rank": "8",
#                 "points": "13",
#                 "matches": "8",
#                 "goal_diff": "4",
#                 "goals_scored": "12",
#                 "goals_conceded": "8",
#                 "lost": "1",
#                 "drawn": "4",
#                 "won": "3",
#                 "team_id": "3",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Manchester United",
#                 "rank": "9",
#                 "points": "13",
#                 "matches": "8",
#                 "goal_diff": "-1",
#                 "goals_scored": "11",
#                 "goals_conceded": "12",
#                 "lost": "3",
#                 "drawn": "1",
#                 "won": "4",
#                 "team_id": "19",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Brighton & Hove Albion",
#                 "rank": "10",
#                 "points": "12",
#                 "matches": "8",
#                 "goal_diff": "1",
#                 "goals_scored": "12",
#                 "goals_conceded": "11",
#                 "lost": "2",
#                 "drawn": "3",
#                 "won": "3",
#                 "team_id": "2",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Aston Villa",
#                 "rank": "11",
#                 "points": "12",
#                 "matches": "8",
#                 "goal_diff": "0",
#                 "goals_scored": "8",
#                 "goals_conceded": "8",
#                 "lost": "2",
#                 "drawn": "3",
#                 "won": "3",
#                 "team_id": "495",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Everton",
#                 "rank": "12",
#                 "points": "11",
#                 "matches": "8",
#                 "goal_diff": "0",
#                 "goals_scored": "9",
#                 "goals_conceded": "9",
#                 "lost": "3",
#                 "drawn": "2",
#                 "won": "3",
#                 "team_id": "20",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Brentford",
#                 "rank": "13",
#                 "points": "10",
#                 "matches": "8",
#                 "goal_diff": "-1",
#                 "goals_scored": "11",
#                 "goals_conceded": "12",
#                 "lost": "4",
#                 "drawn": "1",
#                 "won": "3",
#                 "team_id": "489",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Newcastle United",
#                 "rank": "14",
#                 "points": "9",
#                 "matches": "8",
#                 "goal_diff": "0",
#                 "goals_scored": "7",
#                 "goals_conceded": "7",
#                 "lost": "3",
#                 "drawn": "3",
#                 "won": "2",
#                 "team_id": "9",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Fulham",
#                 "rank": "15",
#                 "points": "8",
#                 "matches": "8",
#                 "goal_diff": "-4",
#                 "goals_scored": "8",
#                 "goals_conceded": "12",
#                 "lost": "4",
#                 "drawn": "2",
#                 "won": "2",
#                 "team_id": "502",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Leeds United",
#                 "rank": "16",
#                 "points": "8",
#                 "matches": "8",
#                 "goal_diff": "-6",
#                 "goals_scored": "7",
#                 "goals_conceded": "13",
#                 "lost": "4",
#                 "drawn": "2",
#                 "won": "2",
#                 "team_id": "1131",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Burnley",
#                 "rank": "17",
#                 "points": "7",
#                 "matches": "8",
#                 "goal_diff": "-6",
#                 "goals_scored": "9",
#                 "goals_conceded": "15",
#                 "lost": "5",
#                 "drawn": "1",
#                 "won": "2",
#                 "team_id": "8",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Nottingham Forest",
#                 "rank": "18",
#                 "points": "5",
#                 "matches": "8",
#                 "goal_diff": "-10",
#                 "goals_scored": "5",
#                 "goals_conceded": "15",
#                 "lost": "5",
#                 "drawn": "2",
#                 "won": "1",
#                 "team_id": "487",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "West Ham United",
#                 "rank": "19",
#                 "points": "4",
#                 "matches": "8",
#                 "goal_diff": "-12",
#                 "goals_scored": "6",
#                 "goals_conceded": "18",
#                 "lost": "6",
#                 "drawn": "1",
#                 "won": "1",
#                 "team_id": "14",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             },
#             {
#                 "league_id": "0",
#                 "season_id": "56",
#                 "name": "Wolverhampton Wanderers",
#                 "rank": "20",
#                 "points": "2",
#                 "matches": "8",
#                 "goal_diff": "-11",
#                 "goals_scored": "5",
#                 "goals_conceded": "16",
#                 "lost": "6",
#                 "drawn": "2",
#                 "won": "0",
#                 "team_id": "497",
#                 "competition_id": "2",
#                 "group_id": "4042",
#                 "group_name": "A",
#                 "stage_name": "Regular Season",
#                 "stage_id": "3498"
#             }
#         ]
#     }
# }

# %%
standings_list = payload["data"]["table"]
formatted_standings = json.dumps(standings_list, indent=4)
print(formatted_standings)
# Out:
# [
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Arsenal",
#         "rank": "1",
#         "points": "19",
#         "matches": "8",
#         "goal_diff": "12",
#         "goals_scored": "15",
#         "goals_conceded": "3",
#         "lost": "1",
#         "drawn": "1",
#         "won": "6",
#         "team_id": "18",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Manchester City",
#         "rank": "2",
#         "points": "16",
#         "matches": "8",
#         "goal_diff": "11",
#         "goals_scored": "17",
#         "goals_conceded": "6",
#         "lost": "2",
#         "drawn": "1",
#         "won": "5",
#         "team_id": "12",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "AFC Bournemouth",
#         "rank": "3",
#         "points": "15",
#         "matches": "8",
#         "goal_diff": "3",
#         "goals_scored": "14",
#         "goals_conceded": "11",
#         "lost": "1",
#         "drawn": "3",
#         "won": "4",
#         "team_id": "1",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Liverpool",
#         "rank": "4",
#         "points": "15",
#         "matches": "8",
#         "goal_diff": "3",
#         "goals_scored": "14",
#         "goals_conceded": "11",
#         "lost": "3",
#         "drawn": "0",
#         "won": "5",
#         "team_id": "7",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Chelsea",
#         "rank": "5",
#         "points": "14",
#         "matches": "8",
#         "goal_diff": "7",
#         "goals_scored": "16",
#         "goals_conceded": "9",
#         "lost": "2",
#         "drawn": "2",
#         "won": "4",
#         "team_id": "17",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Tottenham Hotspur",
#         "rank": "6",
#         "points": "14",
#         "matches": "8",
#         "goal_diff": "7",
#         "goals_scored": "14",
#         "goals_conceded": "7",
#         "lost": "2",
#         "drawn": "2",
#         "won": "4",
#         "team_id": "15",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Sunderland",
#         "rank": "7",
#         "points": "14",
#         "matches": "8",
#         "goal_diff": "3",
#         "goals_scored": "9",
#         "goals_conceded": "6",
#         "lost": "2",
#         "drawn": "2",
#         "won": "4",
#         "team_id": "500",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Crystal Palace",
#         "rank": "8",
#         "points": "13",
#         "matches": "8",
#         "goal_diff": "4",
#         "goals_scored": "12",
#         "goals_conceded": "8",
#         "lost": "1",
#         "drawn": "4",
#         "won": "3",
#         "team_id": "3",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Manchester United",
#         "rank": "9",
#         "points": "13",
#         "matches": "8",
#         "goal_diff": "-1",
#         "goals_scored": "11",
#         "goals_conceded": "12",
#         "lost": "3",
#         "drawn": "1",
#         "won": "4",
#         "team_id": "19",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Brighton & Hove Albion",
#         "rank": "10",
#         "points": "12",
#         "matches": "8",
#         "goal_diff": "1",
#         "goals_scored": "12",
#         "goals_conceded": "11",
#         "lost": "2",
#         "drawn": "3",
#         "won": "3",
#         "team_id": "2",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Aston Villa",
#         "rank": "11",
#         "points": "12",
#         "matches": "8",
#         "goal_diff": "0",
#         "goals_scored": "8",
#         "goals_conceded": "8",
#         "lost": "2",
#         "drawn": "3",
#         "won": "3",
#         "team_id": "495",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Everton",
#         "rank": "12",
#         "points": "11",
#         "matches": "8",
#         "goal_diff": "0",
#         "goals_scored": "9",
#         "goals_conceded": "9",
#         "lost": "3",
#         "drawn": "2",
#         "won": "3",
#         "team_id": "20",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Brentford",
#         "rank": "13",
#         "points": "10",
#         "matches": "8",
#         "goal_diff": "-1",
#         "goals_scored": "11",
#         "goals_conceded": "12",
#         "lost": "4",
#         "drawn": "1",
#         "won": "3",
#         "team_id": "489",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Newcastle United",
#         "rank": "14",
#         "points": "9",
#         "matches": "8",
#         "goal_diff": "0",
#         "goals_scored": "7",
#         "goals_conceded": "7",
#         "lost": "3",
#         "drawn": "3",
#         "won": "2",
#         "team_id": "9",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Fulham",
#         "rank": "15",
#         "points": "8",
#         "matches": "8",
#         "goal_diff": "-4",
#         "goals_scored": "8",
#         "goals_conceded": "12",
#         "lost": "4",
#         "drawn": "2",
#         "won": "2",
#         "team_id": "502",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Leeds United",
#         "rank": "16",
#         "points": "8",
#         "matches": "8",
#         "goal_diff": "-6",
#         "goals_scored": "7",
#         "goals_conceded": "13",
#         "lost": "4",
#         "drawn": "2",
#         "won": "2",
#         "team_id": "1131",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Burnley",
#         "rank": "17",
#         "points": "7",
#         "matches": "8",
#         "goal_diff": "-6",
#         "goals_scored": "9",
#         "goals_conceded": "15",
#         "lost": "5",
#         "drawn": "1",
#         "won": "2",
#         "team_id": "8",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Nottingham Forest",
#         "rank": "18",
#         "points": "5",
#         "matches": "8",
#         "goal_diff": "-10",
#         "goals_scored": "5",
#         "goals_conceded": "15",
#         "lost": "5",
#         "drawn": "2",
#         "won": "1",
#         "team_id": "487",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "West Ham United",
#         "rank": "19",
#         "points": "4",
#         "matches": "8",
#         "goal_diff": "-12",
#         "goals_scored": "6",
#         "goals_conceded": "18",
#         "lost": "6",
#         "drawn": "1",
#         "won": "1",
#         "team_id": "14",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     },
#     {
#         "league_id": "0",
#         "season_id": "56",
#         "name": "Wolverhampton Wanderers",
#         "rank": "20",
#         "points": "2",
#         "matches": "8",
#         "goal_diff": "-11",
#         "goals_scored": "5",
#         "goals_conceded": "16",
#         "lost": "6",
#         "drawn": "2",
#         "won": "0",
#         "team_id": "497",
#         "competition_id": "2",
#         "group_id": "4042",
#         "group_name": "A",
#         "stage_name": "Regular Season",
#         "stage_id": "3498"
#     }
# ]

# %% [markdown]
# # -------------------------TRNAANSFORM-------------------------

# %%
arselnal_points = standings_list[0]['points']
print(arselnal_points)
# Out:
# 19

# %%
rows = []
column_names = [
    "season",
    "position",
    "team__id",
    "team",
    "played",
    "won",
    "draw",
    "lost",
    "goals_for",
    "goals_against",
    "goal_diff",
    "points",
    "form",
]
for club in standings_list:
    season = 2024
    position = club["rank"]
    team_id = club["team_id"]
    team = club["name"]
    played = club["matches"]
    won = club["won"]
    draw = club["drawn"]
    lost = club["lost"]
    goals_for = club["goals_scored"]
    goals_against = club["goals_conceded"]
    goal_diff = club["goal_diff"]
    points = club["points"]
    form = "LLDDWW"

    tuple_of_club_records = (
        season,
        position,
        team_id,
        team,
        played,
        won,
        draw,
        lost,
        goals_for,
        goals_against,
        goal_diff,
        points,
        form,
    )
    rows.append(tuple_of_club_records)

# %%
print(rows)
# Out:
# [(2024, '1', '18', 'Arsenal', '8', '6', '1', '1', '15', '3', '12', '19', 'LLDDWW'), (2024, '2', '12', 'Manchester City', '8', '5', '1', '2', '17', '6', '11', '16', 'LLDDWW'), (2024, '3', '1', 'AFC Bournemouth', '8', '4', '3', '1', '14', '11', '3', '15', 'LLDDWW'), (2024, '4', '7', 'Liverpool', '8', '5', '0', '3', '14', '11', '3', '15', 'LLDDWW'), (2024, '5', '17', 'Chelsea', '8', '4', '2', '2', '16', '9', '7', '14', 'LLDDWW'), (2024, '6', '15', 'Tottenham Hotspur', '8', '4', '2', '2', '14', '7', '7', '14', 'LLDDWW'), (2024, '7', '500', 'Sunderland', '8', '4', '2', '2', '9', '6', '3', '14', 'LLDDWW'), (2024, '8', '3', 'Crystal Palace', '8', '3', '4', '1', '12', '8', '4', '13', 'LLDDWW'), (2024, '9', '19', 'Manchester United', '8', '4', '1', '3', '11', '12', '-1', '13', 'LLDDWW'), (2024, '10', '2', 'Brighton & Hove Albion', '8', '3', '3', '2', '12', '11', '1', '12', 'LLDDWW'), (2024, '11', '495', 'Aston Villa', '8', '3', '3', '2', '8', '8', '0', '12', 'LLDDWW'), (2024, '12', '20', 'Everton', '8', '3', '2', '3', '9', '9', '0', '11', 'LLDDWW'), (2024, '13', '489', 'Brentford', '8', '3', '1', '4', '11', '12', '-1', '10', 'LLDDWW'), (2024, '14', '9', 'Newcastle United', '8', '2', '3', '3', '7', '7', '0', '9', 'LLDDWW'), (2024, '15', '502', 'Fulham', '8', '2', '2', '4', '8', '12', '-4', '8', 'LLDDWW'), (2024, '16', '1131', 'Leeds United', '8', '2', '2', '4', '7', '13', '-6', '8', 'LLDDWW'), (2024, '17', '8', 'Burnley', '8', '2', '1', '5', '9', '15', '-6', '7', 'LLDDWW'), (2024, '18', '487', 'Nottingham Forest', '8', '1', '2', '5', '5', '15', '-10', '5', 'LLDDWW'), (2024, '19', '14', 'West Ham United', '8', '1', '1', '6', '6', '18', '-12', '4', 'LLDDWW'), (2024, '20', '497', 'Wolverhampton Wanderers', '8', '0', '2', '6', '5', '16', '-11', '2', 'LLDDWW')]

# %%
df = pd.DataFrame(rows, columns=column_names)
df.head(20)
# Out:
#     season position team__id                     team played won draw lost  \
# 0     2024        1       18                  Arsenal      8   6    1    1
# 1     2024        2       12          Manchester City      8   5    1    2
# 2     2024        3        1          AFC Bournemouth      8   4    3    1
# 3     2024        4        7                Liverpool      8   5    0    3
# 4     2024        5       17                  Chelsea      8   4    2    2
# 5     2024        6       15        Tottenham Hotspur      8   4    2    2
# 6     2024        7      500               Sunderland      8   4    2    2
# 7     2024        8        3           Crystal Palace      8   3    4    1
# 8     2024        9       19        Manchester United      8   4    1    3
# 9     2024       10        2   Brighton & Hove Albion      8   3    3    2
# 10    2024       11      495              Aston Villa      8   3    3    2
# 11    2024       12       20                  Everton      8   3    2    3
# 12    2024       13      489                Brentford      8   3    1    4
# 13    2024       14        9         Newcastle United      8   2    3    3
# 14    2024       15      502                   Fulham      8   2    2    4
# 15    2024       16     1131             Leeds United      8   2    2    4
# 16    2024       17        8                  Burnley      8   2    1    5
# 17    2024       18      487        Nottingham Forest      8   1    2    5
# 18    2024       19       14          West Ham United      8   1    1    6
# 19    2024       20      497  Wolverhampton Wanderers      8   0    2    6
#
#    goals_for goals_against goal_diff points    form
# 0         15             3        12     19  LLDDWW
# 1         17             6        11     16  LLDDWW
# 2         14            11         3     15  LLDDWW
# 3         14            11         3     15  LLDDWW
# 4         16             9         7     14  LLDDWW
# 5         14             7         7     14  LLDDWW
# 6          9             6         3     14  LLDDWW
# 7         12             8         4     13  LLDDWW
# 8         11            12        -1     13  LLDDWW
# 9         12            11         1     12  LLDDWW
# 10         8             8         0     12  LLDDWW
# 11         9             9         0     11  LLDDWW
# 12        11            12        -1     10  LLDDWW
# 13         7             7         0      9  LLDDWW
# 14         8            12        -4      8  LLDDWW
# 15         7            13        -6      8  LLDDWW
# 16         9            15        -6      7  LLDDWW
# 17         5            15       -10      5  LLDDWW
# 18         6            18       -12      4  LLDDWW
# 19         5            16       -11      2  LLDDWW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         20 non-null     int64
#  1   position       20 non-null     object
#  2   team__id       20 non-null     object
#  3   team           20 non-null     object
#  4   played         20 non-null     object
#  5   won            20 non-null     object
#  6   draw           20 non-null     object
#  7   lost           20 non-null     object
#  8   goals_for      20 non-null     object
#  9   goals_against  20 non-null     object
#  10  goal_diff      20 non-null     object
#  11  points         20 non-null     object
#  12  form           20 non-null     object
# dtypes: int64(1), object(12)
# memory usage: 2.2+ KB

# %% [markdown]
# # ----------------------------------- LOAD -----------------------------------

# %%
MYSQL_HOST = os.getenv("MYSQL_HOST")
MYSQL_PORT = os.getenv("MYSQL_PORT")
MYSQL_USER = os.getenv("MYSQL_USER")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_DATABASE = os.getenv("MYSQL_DATABASE")
print(MYSQL_USER)
# Out:
# postgres

# %%
import psycopg2

# server_conn = connector.connect(
#     host = MYSQL_HOST,
#     port = MYSQL_PORT,
#     user = MYSQL_USER,
#     password = MYSQL_PASSWORD,
#     # connection_timeout = 10,
#     autocommit = False,
#     raise_on_warning=True
# )

try:
    server_conn = psycopg2.connect(
        database=MYSQL_DATABASE,
        host=MYSQL_HOST,
        port=MYSQL_PORT,
        user=MYSQL_USER,
        password=MYSQL_PASSWORD,
    )
    server_conn
    # Open a cursor to perform database operations
    cur = server_conn.cursor()

    # execute a command: Create a test_table
    cur.execute("""CREATE TABLE IF NOT EXISTS test_courses(
    course_id SERIAL PRIMARY KEY,
    course_name VARCHAR (50) UNIQUE NOT NULL,
    course_instructor VARCHAR (100) NOT NULL,
    topic VARCHAR (20) NOT NULL);""")

    cur.execute(
        """
        CREATE TABLE IF NOT EXISTS standings(
        id SERIAL,
        season INT NOT NULL,
        position INT NOT NULL,
        team_id INT NOT NULL,
        team VARCHAR(100) NOT NULL,
        played INT NOT NULL,
        won INT NOT NULL,
        draw INT NOT NULL,
        lost INT NOT NULL,
        goals_for INT NOT NULL,
        goals_against INT NOT NULL,
        goal_diff INT NOT NULL,
        points INT NOT NULL,
        form VARCHAR(6) NOT NULL,
        PRIMARY KEY (season,team_id),
        UNIQUE(season, position)
        );

        """
    )
    print("Connection to PostgresSQL succesfull!")

    sql_table = "standings"
    cur.execute("""
    SELECT EXISTS (
        SELECT FROM information_schema.tables 
        WHERE table_schema = 'public' 
        AND table_name = %s
    )
    """,(sql_table,))

    exists = cur.fetchone()[0]

    if not exists:
        raise SystemExit(f"❌ This table '{sql_table}' is NOT found... please create it.")
    else:
        print(f"✅ This table '{sql_table}' exists!")

except Exception as e:
    print("connection failed!", e)


# finally:
#     if server_conn:
#         # make the changes to the database persistent
#         server_conn.commit()
#         # close cursor and communication with the database
#         cur.close()
#         server_conn.close()
# Out:
# Connection to PostgresSQL succesfull!
# ✅ This table 'standings' exists!

# %%
table_cols = [
    "season",
    "position",
    "team__id",
    "team",
    "played",
    "won",
    "draw",
    "lost",
    "goals_for",
    "goals_against",
    "goal_diff",
    "points",
    "form",
]

standing_df = df[table_cols]

# %%
standings_records_tuples = standing_df.itertuples(index=False, name=None)

list_of_standings_records_tuples = list(standings_records_tuples)

# %%
UPSERT_SQL = f"""
INSERT INTO {sql_table}
(season, position, team_id, team, played, won, draw, lost, goals_for, goals_against, goal_diff, points, form)
VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
ON CONFLICT (season, team_id) DO UPDATE SET
position = EXCLUDED.position,
team = EXCLUDED.team,
played = EXCLUDED.played,
won = EXCLUDED.won,
draw = EXCLUDED.draw,
lost = EXCLUDED.lost,
goals_for = EXCLUDED.goals_for,
goals_against = EXCLUDED.goals_against,
goal_diff = EXCLUDED.goal_diff,
points = EXCLUDED.points,
form = EXCLUDED.form;
"""

# %%
no_of_rows_uploaded_to_mysql = len(list_of_standings_records_tuples)

# %%
try:
    cur.executemany(UPSERT_SQL, list_of_standings_records_tuples)
    server_conn.commit()
    print(f"[SUCCESS] - Upsert attempted for {no_of_rows_uploaded_to_mysql} rows!")

except Exception as e:
    server_conn.rollback()
    print(f"[ERROR] - ROlled back due to this...: {e}")
finally:
    cur.close()
    server_conn.close()
    print("All database connection was closed. \n\nClean up completed.")
# Out:
# [SUCCESS] - Upsert attempted for 20 rows!
# All database connection was closed.
#
# Clean up completed.
